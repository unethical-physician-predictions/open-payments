# %%
from core import *
from udf_open_payments import *

sc = SparkContext.getOrCreate()

# %%
### Functions (created with team) ###

def split_comma(x):
    return list(reader([x], delimiter=',', quotechar='"'))[0]

def is_na(x):  
    """
    To be wrapped with udf.
    Returns 1 if the element in the column is null and 0 otherwise. 
    """
    if x is not None and x is not '':
        return 1
    else:
        return 0

isNa = F.udf(is_na)  

def str_to_bool(x):
    """
    To be wrapped with udf.
    Applied to a colum, maps yes/no and transform them to 1/0 respectively. Nones mapped to 0.
    """
    try:
        if x.lower()=='yes':
            return 1
        else:
            return 0
    except:
        return 0

strToBool = F.udf(str_to_bool)

def max_to_one(x):
    """
    To be wrapped with udf.
    Applied to a colum, maps yes/no and transform them to 1/0 respectively. Nones mapped to 0.
    """
    try:
        if x>1:
            return 1
        else:
            return x
    except:
        return x

maxToOne = F.udf(max_to_one)

def replace_na(x):
    """
    To be wrapped with udf.
    Applied to a colum, maps yes/no and transform them to 1/0 respectively. Nones mapped to 0.
    """
    if x is None:
        return 'blank'
    else:
        return x

replaceNA = F.udf(replace_na)

def check_blanks(x):
    try:
        if len(x)==0:
            return 'blank'
        else: return x
    except:
        return x
    
checkBlankUdf = F.udf(check_blanks)


############ DF COLUMNS FUNCTIONS #################


def TransformColumn(df, cols, userDefinedFunction, newCol=None):
    """
    Gets columns `cols` of `df` and applies a `userDefinedFunction`.
    
    If newCol dictionary is specified:
            - Won't drop cols and will add the new ones with the new name 
                Format ex:
                
                    {'oldCol1':'newCol1','oldCol2':'newCol2',..,'oldColN':'newColN'} (N cols given)
    
    If newCol dictionary is not specified:
            - Will drop the old columns and substitute them by the result of the transformation.
    """
    if newCol is None:
        
        dfNew = df
        for col in cols:
            dfNew = dfNew.withColumn('%s_idx'%col, F.lit(userDefinedFunction(dfNew[col])))\
                         .drop(col)\
                         .withColumnRenamed('%s_idx'%col, col)
        return dfNew
    
    else:
        
        dfNew = df
        for col in cols:
            dfNew = dfNew.withColumn(newCol[col], F.lit(userDefinedFunction(dfNew[col])))
        return dfNew
    
def indexStringColumns(df, cols):
    """
    Modified from ex2 of Lesson5 in https://github.com/dianewoodbridge/2019-msds697-example/
    """
 
    newdf = df
    
    labels_mapping = {}
    for c in cols:
        # For each given column, fits StringIndexerModel.
        sm = StringIndexer(inputCol=c, outputCol=c+"-num").setHandleInvalid("keep")\
                .fit(newdf)
        # Creates a DataFame by putting the transformed values in the new colum with suffix "-num" 
        # then drops the original columns and drops the "-num" suffix. 
        labels_mapping[c] = sm.labels
        newdf = sm.transform(newdf).drop(c)
        newdf = newdf.withColumnRenamed(c+"-num", c)
    return newdf, labels_mapping



def oneHotEncodeColumns(df, cols, dropLast=False):
    """
    Taken from ex2 of Lesson5 in https://github.com/dianewoodbridge/2019-msds697-example/
    """
    newdf = df
    for c in cols:
        # For each given colum, create OneHotEncoder. 
        # dropLast : Whether to drop the last category in the encoded vector (default: true)
        onehotenc = OneHotEncoder(inputCol=c, outputCol=c+"-onehot", dropLast=dropLast)
        newdf = onehotenc.transform(newdf).drop(c)
        newdf = newdf.withColumnRenamed(c+"-onehot", c)

    return newdf

# %% [markdown]
# # Data Loading

# %%
#### Open Payments Research Data Loading ####

# Files downloaded from https://www.cms.gov/OpenPayments/Explore-the-Data/Dataset-Downloads.html and put on s3

file_2017 = "s3://msds697-openpayments/OP_DTL_RSRCH_PGYR2017_P06292018.csv"
file_2016 = "s3://msds697-openpayments/OP_DTL_RSRCH_PGYR2016_P06292018.csv"
file_2015 = "s3://msds697-openpayments/OP_DTL_RSRCH_PGYR2015_P06292018.csv"
file_2014 = "s3://msds697-openpayments/OP_DTL_RSRCH_PGYR2014_P06292018.csv"
file_2013 = "s3://msds697-openpayments/OP_DTL_RSRCH_PGYR2013_P06292018.csv"

text_2017 = sc.textFile(file_2017)
columns_2017 = text_2017.map(split_comma).take(1)
df_text_2017 = text_2017.map(split_comma).toDF(columns_2017[0])

text_2013 = sc.textFile(file_2013)
columns_2013 = text_2013.map(split_comma).take(1)
df_text_2013 = text_2013.map(split_comma).toDF(columns_2013[0])

common_cols = list(set(df_text_2017.columns).intersection(set(df_text_2013.columns)))

files = [file_2016, file_2015, file_2014, file_2013]

df_research = df_text_2017.select([c for c in common_cols])

for file in files:
    text_research = sc.textFile(file)
    columns_research = text_research.map(split_comma).take(1)
    df_text = text_research.map(split_comma).toDF(columns_research[0])
    df_text =  df_text.select([c for c in common_cols])
    df_research = df_research.union(df_text)

# %%
df_research = df_research.withColumn("research_or_general", lit(1.0))

# %%
#### Open Payments General Data Loading ####

g_file_2017 = "s3n://msds697-openpayments/OP_DTL_GNRL_PGYR2017_P06292018.csv"
g_file_2016 = "s3n://msds697-openpayments/OP_DTL_GNRL_PGYR2016_P06292018.csv"
g_file_2015 = "s3n://msds697-openpayments/OP_DTL_GNRL_PGYR2015_P06292018.csv"
g_file_2014 = "s3n://msds697-openpayments/OP_DTL_GNRL_PGYR2014_P06292018.csv"
g_file_2013 = "s3n://msds697-openpayments/OP_DTL_GNRL_PGYR2013_P06292018.csv"

g_text_2017 = sc.textFile(g_file_2017)
g_columns_2017 = g_text_2017.map(split_comma).take(1)
g_df_text_2017 = g_text_2017.map(split_comma).toDF(g_columns_2017[0])

g_text_2013 = sc.textFile(g_file_2013)
g_columns_2013 = g_text_2013.map(split_comma).take(1)
g_df_text_2013 = g_text_2013.map(split_comma).toDF(g_columns_2013[0])

g_common_cols = list(set(g_df_text_2017.columns).intersection(set(g_df_text_2013.columns)))

g_files = [g_file_2016, g_file_2015, g_file_2014, g_file_2013]

df_general = g_df_text_2017.select([c for c in g_common_cols])

for file in g_files:
    text_general = sc.textFile(file)
    columns_general = text_general.map(split_comma).take(1)
    df_text = text_general.map(split_comma).toDF(columns_general[0])
    df_text =  df_text.select([c for c in g_common_cols])
    df_general = df_general.union(df_text)

# %%
df_general = df_general.withColumn("research_or_general", lit(0.0))

# %%
## Combining Data from Research and General ##

all_columns = set(df_general.columns).intersection(set(df_research.columns))

df_general = df_general.select([c for c in all_columns])
df_research = df_research.select([c for c in all_columns])
df_together = df_research.union(df_general)

# %% [markdown]
# # EDA

# %%
df_together.groupBy(df_together["Form_of_Payment_or_Transfer_of_Value"]).count().orderBy("count",ascending=False).show(50, False)
# Out:
# +----------------------------------------------------+--------+
# |Form_of_Payment_or_Transfer_of_Value                |count   |
# +----------------------------------------------------+--------+
# |In-kind items and services                          |41778528|
# |Cash or cash equivalent                             |11210767|
# |Dividend, profit or other return on investment      |1728    |
# |Stock, stock option, or any other ownership interest|726     |
# |Stock                                               |256     |
# |Any other ownership interest                        |222     |
# |Stock option                                        |166     |
# |Form_of_Payment_or_Transfer_of_Value                |10      |
# +----------------------------------------------------+--------+

# %%
Unique_IDs = df1.select('Physician_Profile_ID').distinct()

# %%
Unique_IDs.count()
# Out:
# 976208

# %% [markdown]
# # Processing Data for Modeling

# %%
# %%time
##### DATA PROCESSING ######

df1 = df_together.filter("Total_Amount_of_Payment_USDollars != 0")
df1 = df1.filter("Total_Amount_of_Payment_USDollars == Total_Amount_of_Payment_USDollars")

df2 = df1.filter(df1.Covered_Recipient_Type == 'Covered Recipient Physician')\
            .drop('Covered_Recipient_Type','Teaching_Hospital_ID')

Unique_IDs = df2.select('Physician_Profile_ID').distinct()

Row_Counts = df2.groupby(df2.Physician_Profile_ID).count().withColumnRenamed("count", "Number_of_Columns")

Row_Counts = Unique_IDs.join(Row_Counts, "Physician_Profile_ID", 'left').fillna(0.0)

Avg_Payments_By_Type = df2.groupBy(df2["Physician_Specialty"])\
                       .agg(F.avg("Total_Amount_of_Payment_USDollars").alias("Avg_Amount_of_Payment_USDollars_By_Type"))

Number_of_Cash_Payments = df2.filter(df2.Form_of_Payment_or_Transfer_of_Value == "Cash or cash equivalent")\
           .groupBy(df2.Physician_Profile_ID).count().withColumnRenamed("count", "Number_of_Cash_Payments")

Number_of_Cash_Payments = Unique_IDs.join(Number_of_Cash_Payments, "Physician_Profile_ID", 'left').fillna(10.0)


Number_of_Years = df2.groupby(df2.Physician_Profile_ID)\
                .agg(F.countDistinct('Program_Year'))\
                .withColumnRenamed('count(DISTINCT Program_Year)', 'Number_of_Years')

Number_of_Years = Unique_IDs.join(Number_of_Years, "Physician_Profile_ID", 'left').fillna(10.0)


Distinct_Manufacturers = df2.groupby(df2.Physician_Profile_ID)\
                .agg(F.countDistinct('Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID'))\
                .withColumnRenamed('count(DISTINCT Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID)', 'Distinct_Manufacturers')

Distinct_Manufacturers = Unique_IDs.join(Distinct_Manufacturers, "Physician_Profile_ID", 'left').fillna(10.0)


yesNo_cols = ['Delay_in_Publication_Indicator']

df2 = TransformColumn(df=df1,
                      cols=yesNo_cols,
                      userDefinedFunction=strToBool)


first_cols = ['Recipient_City', 'Recipient_State',
              'Physician_Specialty',
              'Physician_Primary_Type',
              'Physician_License_State_code1','Program_Year',
             ]
sum_cols = ['Total_Amount_of_Payment_USDollars', 
            'Delay_in_Publication_Indicator',
            "research_or_general"]

aggregations = ([F.first(col).alias(col) for col in first_cols ] + [F.sum(col).alias(col) for col in sum_cols ])


df3_2_p = df2.groupBy('Physician_Profile_ID').agg(*aggregations)  

df4_p_na = TransformColumn(df=df3_2_p, cols=df3_2_p.columns, userDefinedFunction=replace_na)

df5_p_aux = TransformColumn(df=df4_p_na, cols=['Physician_Primary_Type',
                                               'Physician_Specialty',
                                               'Physician_License_State_code1'], userDefinedFunction=checkBlankUdf)

df_6 = df5_p_aux.join(Number_of_Years, "Physician_Profile_ID", 'left')\
                .join(Number_of_Cash_Payments, "Physician_Profile_ID", 'left')\
                .join(Row_Counts, "Physician_Profile_ID", 'left')\
                .join(Distinct_Manufacturers, "Physician_Profile_ID", 'left')

df_6 = df_6.join(Avg_Payments_By_Type, "Physician_Specialty", 'left')

new_df = df_6.withColumn("Total_Amount_of_Payment_USDollars_int", df_6["Total_Amount_of_Payment_USDollars"]\
                       .cast("integer")).drop("Total_Amount_of_Payment_USDollars")\
                       .withColumnRenamed("Total_Amount_of_Payment_USDollars_int", "Total_Amount_of_Payment_USDollars")


new_df = new_df.withColumn('avg_Total_Amount_of_Payment_USDollars', new_df.Total_Amount_of_Payment_USDollars/new_df.Number_of_Columns)

new_df_cache = new_df.cache()
# Out:
# CPU times: user 47.1 ms, sys: 10.2 ms, total: 57.4 ms
# Wall time: 4.47 s

# %%
new_df_cache.head()
# Out:
# Row(Physician_Specialty=u'Allopathic & Osteopathic Physicians|Pathology|Clinical Informatics', Physician_Profile_ID=u'1397054', Recipient_City=u'PROVIDENCE', Recipient_State=u'RI', Program_Year=u'2015', Delay_in_Publication_Indicator=0.0, research_or_general=0.0, Physician_Primary_Type=u'Medical Doctor', Physician_License_State_code1=u'RI', Number_of_Years=2, Number_of_Cash_Payments=1, Number_of_Columns=3, Distinct_Manufacturers=2, Avg_Amount_of_Payment_USDollars_By_Type=458.6328571428572, Total_Amount_of_Payment_USDollars=124, avg_Total_Amount_of_Payment_USDollars=41.333333333333336)

# %%
new_df_cache.count()
# Out:
# 976208

# %%
def quantiles_payments(value):

    if value < 258:  
        return 0
    else:
        return 1

quantilesPayments = F.udf(quantiles_payments)

df_quantiles_float = TransformColumn(df=new_df_cache, 
                                     cols=["avg_Total_Amount_of_Payment_USDollars"], 
                                     userDefinedFunction=quantilesPayments)

df_quantiles_float_cache = df_quantiles_float.cache()

# %%
index_cols = [ 'Recipient_City',
 'Recipient_State',
 'Physician_Primary_Type',
 'Physician_Specialty',
 'Physician_License_State_code1',
 'Physician_Specialty']


dfindex, labels_mapping = indexStringColumns(df_quantiles_float_cache.drop('Physician_Profile_ID', 'Program_Year'), 
                                             index_cols)

dfindex_na = TransformColumn(df=dfindex, cols=dfindex.columns, userDefinedFunction=replace_na)

dfhot = oneHotEncodeColumns(dfindex_na, ['Recipient_City',
                                         'Physician_Primary_Type',
                                         'Physician_Specialty',
                                         'Physician_License_State_code1'])

input_cols = ['Number_of_Years',
 'Number_of_Columns',
 'Avg_Amount_of_Payment_USDollars_By_Type',
 'Number_of_Cash_Payments',
 'Recipient_City', 
 'Physician_Primary_Type',
 'Physician_Specialty',
 'Physician_License_State_code1',
 'Distinct_Manufacturers',
 "research_or_general"]

va = VectorAssembler(outputCol="features", inputCols=input_cols)

lpoints = va.setHandleInvalid("skip").transform(dfhot).select("features", "avg_Total_Amount_of_Payment_USDollars")\
                             .withColumnRenamed("avg_Total_Amount_of_Payment_USDollars", "label")

lpoints_int = lpoints.withColumn("int_label", lpoints["label"].cast("integer"))\
                            .drop("label").withColumnRenamed("int_label", "label")

splits = lpoints_int.randomSplit([0.8, 0.2])

payments_train = splits[0].cache()
payments_valid = splits[1].cache()

# %% [markdown]
# # Final Model

# %%
# %%time

dt = DecisionTreeClassifier(maxDepth=20, maxBins= 217, minInstancesPerNode=1, minInfoGain = 0, impurity='gini')
dtmodel = dt.fit(payments_train)
# Out:
# CPU times: user 701 ms, sys: 164 ms, total: 866 ms
# Wall time: 52min 43s

# %%
print(dtmodel._call_java('toDebugString'))
# Out:
# DecisionTreeClassificationModel (uid=DecisionTreeClassifier_bf6f45f77692) of depth 20 with 23867 nodes
#   If (feature 20268 <= 0.5)
#    If (feature 3 <= 23.5)
#     If (feature 2 <= 222.56308482335868)
#      If (feature 2 <= 152.9139084590851)
#       If (feature 3 <= 9.5)
#        If (feature 20267 <= 4.5)
#         If (feature 3 <= 2.5)
#          If (feature 20267 <= 1.5)
#           If (feature 1 <= 2.5)
#            If (feature 2 <= 136.8641030926666)
#             If (feature 11 in {1.0})
#              If (feature 19694 in {1.0})
#               Predict: 0.0
#              Else (feature 19694 not in {1.0})
#               If (feature 2 <= 40.055673947170746)
#                Predict: 1.0
#               Else (feature 2 > 40.055673947170746)
#                If (feature 1 <= 1.5)
#                 If (feature 19705 in {1.0})
#                  Predict: 0.0
#                 Else (feature 19705 not in {1.0})
#                  If (feature 19742 in {1.0})
#                   Predict: 1.0
#                  Else (feature 19742 not in {1.0})
#                   If (feature 20212 in {1.0})
#                    Predict: 1.0
#                   Else (feature 20212 not in {1.0})
#                    Predict: 0.0
#                Else (feature 1 > 1.5)
#                 If (feature 0 <= 1.5)
#                  Predict: 1.0
#                 Else (feature 0 > 1.5)
#                  Predict: 0.0
#             Else (feature 11 not in {1.0})
#              If (feature 1 <= 1.5)
#               If (feature 2 <= 52.16374070317782)
#                If (feature 128 in {1.0})
#                 If (feature 2 <= 39.264531375230774)
#                  Predict: 1.0
#                 Else (feature 2 > 39.264531375230774)
#                  Predict: 0.0
#                Else (feature 128 not in {1.0})
#                 If (feature 217 in {1.0})
#                  Predict: 1.0
#                 Else (feature 217 not in {1.0})
#                  If (feature 224 in {1.0})
#                   Predict: 1.0
#                  Else (feature 224 not in {1.0})
#                   If (feature 305 in {1.0})
#                    Predict: 1.0
#                   Else (feature 305 not in {1.0})
#                    If (feature 310 in {1.0})
#                     Predict: 1.0
#                    Else (feature 310 not in {1.0})
#                     If (feature 346 in {1.0})
#                      Predict: 1.0
#                     Else (feature 346 not in {1.0})
#                      If (feature 406 in {1.0})
#                       Predict: 1.0
#                      Else (feature 406 not in {1.0})
#                       Predict: 0.0
#               Else (feature 2 > 52.16374070317782)
#                If (feature 135 in {1.0})
#                 If (feature 2 <= 92.96901781479114)
#                  If (feature 2 <= 71.69213998942443)
#                   If (feature 2 <= 63.775164346606665)
#                    Predict: 0.0
#                   Else (feature 2 > 63.775164346606665)
#                    Predict: 1.0
#                  Else (feature 2 > 71.69213998942443)
#                   Predict: 1.0
#                 Else (feature 2 > 92.96901781479114)
#                  Predict: 0.0
#                Else (feature 135 not in {1.0})
#                 If (feature 91 in {1.0})
#                  If (feature 2 <= 63.775164346606665)
#                   Predict: 1.0
#                  Else (feature 2 > 63.775164346606665)
#                   Predict: 0.0
#                 Else (feature 91 not in {1.0})
#                  If (feature 478 in {1.0})
#                   If (feature 2 <= 63.775164346606665)
#                    If (feature 20206 in {0.0})
#                     Predict: 0.0
#                    Else (feature 20206 not in {0.0})
#                     Predict: 1.0
#                   Else (feature 2 > 63.775164346606665)
#                    Predict: 1.0
#                  Else (feature 478 not in {1.0})
#                   If (feature 19736 in {1.0})
#                    If (feature 52 in {1.0})
#                     Predict: 1.0
#                    Else (feature 52 not in {1.0})
#                     If (feature 7 in {1.0})
#                      Predict: 1.0
#                     Else (feature 7 not in {1.0})
#                      If (feature 20212 in {1.0})
#                       Predict: 1.0
#                      Else (feature 20212 not in {1.0})
#                       Predict: 0.0
#                   Else (feature 19736 not in {1.0})
#                    If (feature 224 in {1.0})
#                     Predict: 1.0
#                    Else (feature 224 not in {1.0})
#                     If (feature 19797 in {1.0})
#                      Predict: 1.0
#                     Else (feature 19797 not in {1.0})
#                      If (feature 20073 in {1.0})
#                       Predict: 1.0
#                      Else (feature 20073 not in {1.0})
#                       Predict: 0.0
#              Else (feature 1 > 1.5)
#               If (feature 3 <= 1.5)
#                If (feature 0 <= 1.5)
#                 If (feature 19694 in {1.0})
#                  If (feature 670 in {0.0})
#                   Predict: 0.0
#                  Else (feature 670 not in {0.0})
#                   Predict: 1.0
#                 Else (feature 19694 not in {1.0})
#                  If (feature 19681 in {0.0})
#                   If (feature 2 <= 63.775164346606665)
#                    Predict: 1.0
#                   Else (feature 2 > 63.775164346606665)
#                    If (feature 117 in {1.0})
#                     Predict: 1.0
#                    Else (feature 117 not in {1.0})
#                     If (feature 228 in {1.0})
#                      Predict: 1.0
#                     Else (feature 228 not in {1.0})
#                      If (feature 1472 in {1.0})
#                       Predict: 1.0
#                      Else (feature 1472 not in {1.0})
#                       Predict: 0.0
#                  Else (feature 19681 not in {0.0})
#                   If (feature 23 in {1.0})
#                    Predict: 0.0
#                   Else (feature 23 not in {1.0})
#                    If (feature 29 in {1.0})
#                     Predict: 0.0
#                    Else (feature 29 not in {1.0})
#                     If (feature 19797 in {1.0})
#                      Predict: 0.0
#                     Else (feature 19797 not in {1.0})
#                      Predict: 1.0
#                Else (feature 0 > 1.5)
#                 If (feature 66 in {1.0})
#                  Predict: 1.0
#                 Else (feature 66 not in {1.0})
#                  If (feature 19690 in {0.0})
#                   If (feature 62 in {1.0})
#                    Predict: 1.0
#                   Else (feature 62 not in {1.0})
#                    If (feature 141 in {1.0})
#                     Predict: 1.0
#                    Else (feature 141 not in {1.0})
#                     If (feature 176 in {1.0})
#                      Predict: 1.0
#                     Else (feature 176 not in {1.0})
#                      If (feature 810 in {1.0})
#                       Predict: 1.0
#                      Else (feature 810 not in {1.0})
#                       Predict: 0.0
#                  Else (feature 19690 not in {0.0})
#                   If (feature 45 in {1.0})
#                    Predict: 1.0
#                   Else (feature 45 not in {1.0})
#                    If (feature 63 in {1.0})
#                     Predict: 1.0
#                    Else (feature 63 not in {1.0})
#                     If (feature 372 in {1.0})
#                      Predict: 1.0
#                     Else (feature 372 not in {1.0})
#                      If (feature 586 in {1.0})
#                       Predict: 1.0
#                      Else (feature 586 not in {1.0})
#                       Predict: 0.0
#               Else (feature 3 > 1.5)
#                If (feature 20220 in {1.0})
#                 If (feature 2 <= 85.48276497678137)
#                  If (feature 19689 in {0.0})
#                   Predict: 0.0
#                  Else (feature 19689 not in {0.0})
#                   If (feature 21 in {1.0})
#                    Predict: 1.0
#                   Else (feature 21 not in {1.0})
#                    If (feature 89 in {1.0})
#                     Predict: 1.0
#                    Else (feature 89 not in {1.0})
#                     If (feature 14 in {0.0})
#                      If (feature 8573 in {0.0})
#                       Predict: 0.0
#                      Else (feature 8573 not in {0.0})
#                       Predict: 1.0
#                     Else (feature 14 not in {0.0})
#                      If (feature 0 <= 1.5)
#                       Predict: 1.0
#                      Else (feature 0 > 1.5)
#                       Predict: 0.0
#                 Else (feature 2 > 85.48276497678137)
#                  Predict: 1.0
#                Else (feature 20220 not in {1.0})
#                 If (feature 36 in {1.0})
#                  Predict: 1.0
#                 Else (feature 36 not in {1.0})
#                  If (feature 135 in {1.0})
#                   Predict: 1.0
#                  Else (feature 135 not in {1.0})
#                   If (feature 190 in {1.0})
#                    Predict: 1.0
#                   Else (feature 190 not in {1.0})
#                    If (feature 23 in {1.0})
#                     If (feature 2 <= 108.88017396489398)
#                      If (feature 2 <= 63.775164346606665)
#                       Predict: 0.0
#                      Else (feature 2 > 63.775164346606665)
#                       Predict: 1.0
#                     Else (feature 2 > 108.88017396489398)
#                      If (feature 0 <= 1.5)
#                       Predict: 0.0
#                      Else (feature 0 > 1.5)
#                       Predict: 1.0
#                    Else (feature 23 not in {1.0})
#                     If (feature 290 in {1.0})
#                      Predict: 1.0
#                     Else (feature 290 not in {1.0})
#                      If (feature 379 in {1.0})
#                       Predict: 1.0
#                      Else (feature 379 not in {1.0})
#                       Predict: 0.0
#            Else (feature 2 > 136.8641030926666)
#             If (feature 2 <= 137.28688600971873)
#              If (feature 20214 in {1.0})
#               If (feature 0 <= 1.5)
#                Predict: 1.0
#               Else (feature 0 > 1.5)
#                If (feature 3 <= 1.5)
#                 Predict: 0.0
#                Else (feature 3 > 1.5)
#                 Predict: 1.0
#              Else (feature 20214 not in {1.0})
#               If (feature 20209 in {1.0})
#                Predict: 0.0
#               Else (feature 20209 not in {1.0})
#                If (feature 27 in {1.0})
#                 Predict: 1.0
#                Else (feature 27 not in {1.0})
#                 If (feature 52 in {1.0})
#                  Predict: 1.0
#                 Else (feature 52 not in {1.0})
#                  If (feature 20256 in {1.0})
#                   Predict: 1.0
#                  Else (feature 20256 not in {1.0})
#                   If (feature 20218 in {1.0})
#                    If (feature 11253 in {1.0})
#                     Predict: 0.0
#                    Else (feature 11253 not in {1.0})
#                     Predict: 1.0
#                   Else (feature 20218 not in {1.0})
#                    If (feature 20229 in {1.0})
#                     If (feature 310 in {1.0})
#                      If (feature 1 <= 1.5)
#                       Predict: 0.0
#                      Else (feature 1 > 1.5)
#                       Predict: 1.0
#                     Else (feature 310 not in {1.0})
#                      Predict: 1.0
#                    Else (feature 20229 not in {1.0})
#                     If (feature 16 in {1.0})
#                      Predict: 1.0
#                     Else (feature 16 not in {1.0})
#                      If (feature 18 in {1.0})
#                       Predict: 1.0
#                      Else (feature 18 not in {1.0})
#                       Predict: 0.0
#             Else (feature 2 > 137.28688600971873)
#              If (feature 1 <= 1.5)
#               If (feature 69 in {1.0})
#                Predict: 1.0
#               Else (feature 69 not in {1.0})
#                If (feature 102 in {1.0})
#                 Predict: 1.0
#                Else (feature 102 not in {1.0})
#                 If (feature 244 in {1.0})
#                  Predict: 1.0
#                 Else (feature 244 not in {1.0})
#                  If (feature 79 in {1.0})
#                   Predict: 1.0
#                  Else (feature 79 not in {1.0})
#                   If (feature 279 in {1.0})
#                    Predict: 1.0
#                   Else (feature 279 not in {1.0})
#                    If (feature 20233 in {1.0})
#                     If (feature 2 <= 141.56717716629112)
#                      Predict: 1.0
#                     Else (feature 2 > 141.56717716629112)
#                      If (feature 2 <= 149.99905198659314)
#                       Predict: 0.0
#                      Else (feature 2 > 149.99905198659314)
#                       Predict: 1.0
#                    Else (feature 20233 not in {1.0})
#                     If (feature 83 in {1.0})
#                      Predict: 1.0
#                     Else (feature 83 not in {1.0})
#                      If (feature 140 in {1.0})
#                       Predict: 1.0
#                      Else (feature 140 not in {1.0})
#                       Predict: 0.0
#              Else (feature 1 > 1.5)
#               If (feature 3 <= 1.5)
#                If (feature 2 <= 149.99905198659314)
#                 If (feature 945 in {0.0})
#                  If (feature 1407 in {0.0})
#                   Predict: 0.0
#                  Else (feature 1407 not in {0.0})
#                   Predict: 1.0
#                 Else (feature 945 not in {0.0})
#                  Predict: 1.0
#                Else (feature 2 > 149.99905198659314)
#                 If (feature 20205 in {1.0})
#                  Predict: 0.0
#                 Else (feature 20205 not in {1.0})
#                  If (feature 61 in {1.0})
#                   Predict: 0.0
#                  Else (feature 61 not in {1.0})
#                   If (feature 111 in {1.0})
#                    Predict: 0.0
#                   Else (feature 111 not in {1.0})
#                    If (feature 1864 in {1.0})
#                     Predict: 0.0
#                    Else (feature 1864 not in {1.0})
#                     If (feature 6181 in {1.0})
#                      Predict: 0.0
#                     Else (feature 6181 not in {1.0})
#                      Predict: 1.0
#               Else (feature 3 > 1.5)
#                If (feature 0 <= 1.5)
#                 If (feature 20215 in {1.0})
#                  Predict: 1.0
#                 Else (feature 20215 not in {1.0})
#                  If (feature 35 in {1.0})
#                   Predict: 1.0
#                  Else (feature 35 not in {1.0})
#                   If (feature 36 in {1.0})
#                    Predict: 1.0
#                   Else (feature 36 not in {1.0})
#                    If (feature 2 <= 150.4962989609648)
#                     If (feature 2 <= 149.99905198659314)
#                      If (feature 11 in {1.0})
#                       Predict: 1.0
#                      Else (feature 11 not in {1.0})
#                       Predict: 0.0
#                     Else (feature 2 > 149.99905198659314)
#                      Predict: 1.0
#                    Else (feature 2 > 150.4962989609648)
#                     If (feature 79 in {1.0})
#                      Predict: 1.0
#                     Else (feature 79 not in {1.0})
#                      If (feature 119 in {1.0})
#                       Predict: 1.0
#                      Else (feature 119 not in {1.0})
#                       Predict: 0.0
#                Else (feature 0 > 1.5)
#                 If (feature 19 in {0.0})
#                  If (feature 520 in {0.0})
#                   Predict: 0.0
#                  Else (feature 520 not in {0.0})
#                   Predict: 1.0
#                 Else (feature 19 not in {0.0})
#                  Predict: 1.0
#           Else (feature 1 > 2.5)
#            If (feature 19681 in {0.0})
#             If (feature 0 <= 2.5)
#              If (feature 19682 in {1.0})
#               If (feature 1 <= 13.5)
#                Predict: 0.0
#               Else (feature 1 > 13.5)
#                Predict: 1.0
#              Else (feature 19682 not in {1.0})
#               If (feature 20208 in {1.0})
#                Predict: 0.0
#               Else (feature 20208 not in {1.0})
#                If (feature 20235 in {1.0})
#                 Predict: 0.0
#                Else (feature 20235 not in {1.0})
#                 If (feature 1 <= 10.5)
#                  If (feature 1 <= 4.5)
#                   If (feature 2 <= 88.87565916021154)
#                    Predict: 0.0
#                   Else (feature 2 > 88.87565916021154)
#                    If (feature 20207 in {1.0})
#                     Predict: 1.0
#                    Else (feature 20207 not in {1.0})
#                     If (feature 1 <= 3.5)
#                      If (feature 29 in {1.0})
#                       Predict: 0.0
#                      Else (feature 29 not in {1.0})
#                       Predict: 1.0
#                     Else (feature 1 > 3.5)
#                      If (feature 1794 in {0.0})
#                       Predict: 0.0
#                      Else (feature 1794 not in {0.0})
#                       Predict: 1.0
#                  Else (feature 1 > 4.5)
#                   If (feature 1291 in {1.0})
#                    Predict: 0.0
#                   Else (feature 1291 not in {1.0})
#                    If (feature 2042 in {1.0})
#                     Predict: 0.0
#                    Else (feature 2042 not in {1.0})
#                     Predict: 1.0
#                 Else (feature 1 > 10.5)
#                  If (feature 376 in {0.0})
#                   Predict: 0.0
#                  Else (feature 376 not in {0.0})
#                   Predict: 1.0
#             Else (feature 0 > 2.5)
#              If (feature 20208 in {1.0})
#               Predict: 1.0
#              Else (feature 20208 not in {1.0})
#               If (feature 183 in {1.0})
#                Predict: 1.0
#               Else (feature 183 not in {1.0})
#                If (feature 863 in {1.0})
#                 Predict: 1.0
#                Else (feature 863 not in {1.0})
#                 If (feature 1403 in {0.0})
#                  If (feature 3268 in {0.0})
#                   Predict: 0.0
#                  Else (feature 3268 not in {0.0})
#                   Predict: 1.0
#                 Else (feature 1403 not in {0.0})
#                  Predict: 1.0
#            Else (feature 19681 not in {0.0})
#             If (feature 0 <= 1.5)
#              If (feature 1 <= 15.5)
#               If (feature 24 in {1.0})
#                If (feature 2 <= 112.06327889249323)
#                 Predict: 0.0
#                Else (feature 2 > 112.06327889249323)
#                 Predict: 1.0
#               Else (feature 24 not in {1.0})
#                If (feature 56 in {1.0})
#                 Predict: 0.0
#                Else (feature 56 not in {1.0})
#                 If (feature 90 in {1.0})
#                  Predict: 0.0
#                 Else (feature 90 not in {1.0})
#                  If (feature 131 in {1.0})
#                   Predict: 0.0
#                  Else (feature 131 not in {1.0})
#                   If (feature 157 in {1.0})
#                    Predict: 0.0
#                   Else (feature 157 not in {1.0})
#                    If (feature 353 in {1.0})
#                     Predict: 0.0
#                    Else (feature 353 not in {1.0})
#                     If (feature 385 in {1.0})
#                      Predict: 0.0
#                     Else (feature 385 not in {1.0})
#                      If (feature 877 in {1.0})
#                       Predict: 0.0
#                      Else (feature 877 not in {1.0})
#                       Predict: 1.0
#              Else (feature 1 > 15.5)
#               If (feature 1 <= 18.5)
#                Predict: 0.0
#               Else (feature 1 > 18.5)
#                Predict: 1.0
#             Else (feature 0 > 1.5)
#              If (feature 1 <= 5.5)
#               If (feature 0 <= 2.5)
#                If (feature 20209 in {1.0})
#                 Predict: 0.0
#                Else (feature 20209 not in {1.0})
#                 If (feature 20223 in {1.0})
#                  Predict: 0.0
#                 Else (feature 20223 not in {1.0})
#                  If (feature 19705 in {1.0})
#                   If (feature 12 in {0.0})
#                    Predict: 0.0
#                   Else (feature 12 not in {0.0})
#                    Predict: 1.0
#                  Else (feature 19705 not in {1.0})
#                   If (feature 20207 in {1.0})
#                    Predict: 0.0
#                   Else (feature 20207 not in {1.0})
#                    If (feature 3 <= 1.5)
#                     If (feature 4 in {1.0})
#                      Predict: 1.0
#                     Else (feature 4 not in {1.0})
#                      If (feature 19689 in {1.0})
#                       Predict: 0.0
#                      Else (feature 19689 not in {1.0})
#                       Predict: 1.0
#                    Else (feature 3 > 1.5)
#                     If (feature 5 in {1.0})
#                      Predict: 0.0
#                     Else (feature 5 not in {1.0})
#                      If (feature 1530 in {1.0})
#                       Predict: 0.0
#                      Else (feature 1530 not in {1.0})
#                       Predict: 1.0
#               Else (feature 0 > 2.5)
#                If (feature 2 <= 63.775164346606665)
#                 If (feature 1 <= 3.5)
#                  Predict: 1.0
#                 Else (feature 1 > 3.5)
#                  If (feature 1531 in {0.0})
#                   Predict: 0.0
#                  Else (feature 1531 not in {0.0})
#                   Predict: 1.0
#                Else (feature 2 > 63.775164346606665)
#                 Predict: 0.0
#              Else (feature 1 > 5.5)
#               If (feature 20230 in {1.0})
#                Predict: 0.0
#               Else (feature 20230 not in {1.0})
#                If (feature 4 in {1.0})
#                 If (feature 0 <= 2.5)
#                  Predict: 1.0
#                 Else (feature 0 > 2.5)
#                  Predict: 0.0
#                Else (feature 4 not in {1.0})
#                 If (feature 20208 in {1.0})
#                  If (feature 2 <= 71.69213998942443)
#                   Predict: 0.0
#                  Else (feature 2 > 71.69213998942443)
#                   Predict: 1.0
#                 Else (feature 20208 not in {1.0})
#                  If (feature 33 in {1.0})
#                   Predict: 0.0
#                  Else (feature 33 not in {1.0})
#                   If (feature 20205 in {1.0})
#                    If (feature 1 <= 7.5)
#                     Predict: 0.0
#                    Else (feature 1 > 7.5)
#                     If (feature 1 <= 17.5)
#                      If (feature 2323 in {1.0})
#                       Predict: 0.0
#                      Else (feature 2323 not in {1.0})
#                       Predict: 1.0
#                     Else (feature 1 > 17.5)
#                      Predict: 0.0
#                   Else (feature 20205 not in {1.0})
#                    If (feature 0 <= 3.5)
#                     If (feature 113 in {1.0})
#                      Predict: 0.0
#                     Else (feature 113 not in {1.0})
#                      If (feature 1575 in {1.0})
#                       Predict: 0.0
#                      Else (feature 1575 not in {1.0})
#                       Predict: 1.0
#                    Else (feature 0 > 3.5)
#                     If (feature 2 <= 40.055673947170746)
#                      Predict: 1.0
#                     Else (feature 2 > 40.055673947170746)
#                      Predict: 0.0
#          Else (feature 20267 > 1.5)
#           If (feature 1 <= 6.5)
#            If (feature 11 in {1.0})
#             If (feature 1 <= 4.5)
#              If (feature 3 <= 1.5)
#               If (feature 19705 in {1.0})
#                If (feature 20227 in {1.0})
#                 Predict: 0.0
#                Else (feature 20227 not in {1.0})
#                 If (feature 0 <= 1.5)
#                  Predict: 1.0
#                 Else (feature 0 > 1.5)
#                  If (feature 1 <= 2.5)
#                   Predict: 0.0
#                  Else (feature 1 > 2.5)
#                   Predict: 1.0
#               Else (feature 19705 not in {1.0})
#                If (feature 19725 in {1.0})
#                 If (feature 1 <= 2.5)
#                  Predict: 0.0
#                 Else (feature 1 > 2.5)
#                  Predict: 1.0
#                Else (feature 19725 not in {1.0})
#                 If (feature 19726 in {1.0})
#                  Predict: 1.0
#                 Else (feature 19726 not in {1.0})
#                  If (feature 20267 <= 2.5)
#                   If (feature 1 <= 2.5)
#                    If (feature 19711 in {0.0})
#                     Predict: 0.0
#                    Else (feature 19711 not in {0.0})
#                     Predict: 1.0
#                   Else (feature 1 > 2.5)
#                    If (feature 2 <= 63.775164346606665)
#                     Predict: 1.0
#                    Else (feature 2 > 63.775164346606665)
#                     If (feature 1 <= 3.5)
#                      Predict: 0.0
#                     Else (feature 1 > 3.5)
#                      If (feature 0 <= 3.5)
#                       Predict: 1.0
#                      Else (feature 0 > 3.5)
#                       Predict: 0.0
#                  Else (feature 20267 > 2.5)
#                   Predict: 0.0
#              Else (feature 3 > 1.5)
#               If (feature 19711 in {1.0})
#                Predict: 1.0
#               Else (feature 19711 not in {1.0})
#                If (feature 19738 in {1.0})
#                 Predict: 1.0
#                Else (feature 19738 not in {1.0})
#                 If (feature 19800 in {1.0})
#                  Predict: 1.0
#                 Else (feature 19800 not in {1.0})
#                  If (feature 20242 in {1.0})
#                   Predict: 1.0
#                  Else (feature 20242 not in {1.0})
#                   If (feature 2 <= 124.3039952243114)
#                    If (feature 19681 in {0.0})
#                     If (feature 1 <= 3.5)
#                      If (feature 2 <= 63.775164346606665)
#                       Predict: 1.0
#                      Else (feature 2 > 63.775164346606665)
#                       Predict: 0.0
#                     Else (feature 1 > 3.5)
#                      Predict: 1.0
#                    Else (feature 19681 not in {0.0})
#                     If (feature 2 <= 71.69213998942443)
#                      If (feature 20267 <= 3.5)
#                       Predict: 0.0
#                      Else (feature 20267 > 3.5)
#                       Predict: 1.0
#                     Else (feature 2 > 71.69213998942443)
#                      Predict: 0.0
#                   Else (feature 2 > 124.3039952243114)
#                    If (feature 1 <= 2.5)
#                     If (feature 0 <= 1.5)
#                      Predict: 0.0
#                     Else (feature 0 > 1.5)
#                      Predict: 1.0
#                    Else (feature 1 > 2.5)
#                     Predict: 0.0
#             Else (feature 1 > 4.5)
#              If (feature 19681 in {0.0})
#               Predict: 0.0
#              Else (feature 19681 not in {0.0})
#               If (feature 20214 in {0.0})
#                Predict: 0.0
#               Else (feature 20214 not in {0.0})
#                If (feature 20267 <= 2.5)
#                 If (feature 3 <= 1.5)
#                  Predict: 1.0
#                 Else (feature 3 > 1.5)
#                  If (feature 0 <= 1.5)
#                   Predict: 1.0
#                  Else (feature 0 > 1.5)
#                   If (feature 2 <= 40.055673947170746)
#                    Predict: 1.0
#                   Else (feature 2 > 40.055673947170746)
#                    Predict: 0.0
#                Else (feature 20267 > 2.5)
#                 If (feature 19694 in {1.0})
#                  Predict: 1.0
#                 Else (feature 19694 not in {1.0})
#                  If (feature 0 <= 2.5)
#                   If (feature 20267 <= 3.5)
#                    If (feature 2 <= 63.775164346606665)
#                     If (feature 1 <= 5.5)
#                      Predict: 0.0
#                     Else (feature 1 > 5.5)
#                      Predict: 1.0
#                    Else (feature 2 > 63.775164346606665)
#                     Predict: 0.0
#                   Else (feature 20267 > 3.5)
#                    Predict: 1.0
#                  Else (feature 0 > 2.5)
#                   Predict: 0.0
#            Else (feature 11 not in {1.0})
#             If (feature 3 <= 1.5)
#              If (feature 20267 <= 2.5)
#               If (feature 1 <= 3.5)
#                If (feature 19711 in {1.0})
#                 If (feature 1 <= 2.5)
#                  If (feature 7 in {1.0})
#                   Predict: 1.0
#                  Else (feature 7 not in {1.0})
#                   If (feature 19 in {1.0})
#                    Predict: 1.0
#                   Else (feature 19 not in {1.0})
#                    If (feature 42 in {1.0})
#                     Predict: 1.0
#                    Else (feature 42 not in {1.0})
#                     If (feature 50 in {1.0})
#                      Predict: 1.0
#                     Else (feature 50 not in {1.0})
#                      If (feature 68 in {1.0})
#                       Predict: 1.0
#                      Else (feature 68 not in {1.0})
#                       Predict: 0.0
#                 Else (feature 1 > 2.5)
#                  If (feature 20208 in {1.0})
#                   Predict: 1.0
#                  Else (feature 20208 not in {1.0})
#                   If (feature 20222 in {1.0})
#                    Predict: 1.0
#                   Else (feature 20222 not in {1.0})
#                    If (feature 74 in {1.0})
#                     Predict: 1.0
#                    Else (feature 74 not in {1.0})
#                     If (feature 619 in {1.0})
#                      Predict: 1.0
#                     Else (feature 619 not in {1.0})
#                      If (feature 934 in {0.0})
#                       Predict: 0.0
#                      Else (feature 934 not in {0.0})
#                       Predict: 1.0
#                Else (feature 19711 not in {1.0})
#                 If (feature 335 in {1.0})
#                  Predict: 1.0
#                 Else (feature 335 not in {1.0})
#                  If (feature 367 in {1.0})
#                   Predict: 1.0
#                  Else (feature 367 not in {1.0})
#                   If (feature 449 in {1.0})
#                    Predict: 1.0
#                   Else (feature 449 not in {1.0})
#                    If (feature 802 in {1.0})
#                     Predict: 1.0
#                    Else (feature 802 not in {1.0})
#                     If (feature 893 in {1.0})
#                      Predict: 1.0
#                     Else (feature 893 not in {1.0})
#                      If (feature 970 in {1.0})
#                       Predict: 1.0
#                      Else (feature 970 not in {1.0})
#                       Predict: 0.0
#               Else (feature 1 > 3.5)
#                If (feature 19695 in {1.0})
#                 If (feature 0 <= 2.5)
#                  If (feature 20205 in {1.0})
#                   Predict: 1.0
#                  Else (feature 20205 not in {1.0})
#                   If (feature 20213 in {1.0})
#                    Predict: 0.0
#                   Else (feature 20213 not in {1.0})
#                    If (feature 0 <= 1.5)
#                     Predict: 1.0
#                    Else (feature 0 > 1.5)
#                     If (feature 20212 in {1.0})
#                      Predict: 1.0
#                     Else (feature 20212 not in {1.0})
#                      If (feature 5 in {1.0})
#                       Predict: 1.0
#                      Else (feature 5 not in {1.0})
#                       Predict: 0.0
#                 Else (feature 0 > 2.5)
#                  If (feature 15 in {0.0})
#                   Predict: 0.0
#                  Else (feature 15 not in {0.0})
#                   Predict: 1.0
#                Else (feature 19695 not in {1.0})
#                 If (feature 770 in {1.0})
#                  Predict: 1.0
#                 Else (feature 770 not in {1.0})
#                  If (feature 7 in {1.0})
#                   If (feature 19694 in {1.0})
#                    Predict: 1.0
#                   Else (feature 19694 not in {1.0})
#                    If (feature 0 <= 1.5)
#                     If (feature 1 <= 4.5)
#                      If (feature 2 <= 40.055673947170746)
#                       Predict: 1.0
#                      Else (feature 2 > 40.055673947170746)
#                       Predict: 0.0
#                     Else (feature 1 > 4.5)
#                      Predict: 1.0
#                    Else (feature 0 > 1.5)
#                     If (feature 0 <= 2.5)
#                      Predict: 0.0
#                     Else (feature 0 > 2.5)
#                      If (feature 2 <= 40.055673947170746)
#                       Predict: 1.0
#                      Else (feature 2 > 40.055673947170746)
#                       Predict: 0.0
#                  Else (feature 7 not in {1.0})
#                   If (feature 19742 in {1.0})
#                    If (feature 1 <= 4.5)
#                     If (feature 719 in {0.0})
#                      Predict: 0.0
#                     Else (feature 719 not in {0.0})
#                      Predict: 1.0
#                    Else (feature 1 > 4.5)
#                     Predict: 1.0
#                   Else (feature 19742 not in {1.0})
#                    If (feature 0 <= 2.5)
#                     If (feature 19694 in {1.0})
#                      If (feature 0 <= 1.5)
#                       Predict: 1.0
#                      Else (feature 0 > 1.5)
#                       Predict: 0.0
#                     Else (feature 19694 not in {1.0})
#                      Predict: 0.0
#                    Else (feature 0 > 2.5)
#                     If (feature 25 in {1.0})
#                      Predict: 1.0
#                     Else (feature 25 not in {1.0})
#                      If (feature 62 in {1.0})
#                       Predict: 1.0
#                      Else (feature 62 not in {1.0})
#                       Predict: 0.0
#              Else (feature 20267 > 2.5)
#               If (feature 1575 in {1.0})
#                Predict: 1.0
#               Else (feature 1575 not in {1.0})
#                If (feature 1729 in {1.0})
#                 Predict: 1.0
#                Else (feature 1729 not in {1.0})
#                 If (feature 91 in {1.0})
#                  If (feature 0 <= 2.5)
#                   Predict: 0.0
#                  Else (feature 0 > 2.5)
#                   If (feature 2 <= 71.69213998942443)
#                    If (feature 1 <= 3.5)
#                     Predict: 1.0
#                    Else (feature 1 > 3.5)
#                     If (feature 1 <= 4.5)
#                      If (feature 20267 <= 3.5)
#                       Predict: 0.0
#                      Else (feature 20267 > 3.5)
#                       Predict: 1.0
#                     Else (feature 1 > 4.5)
#                      Predict: 1.0
#                   Else (feature 2 > 71.69213998942443)
#                    Predict: 0.0
#                 Else (feature 91 not in {1.0})
#                  If (feature 61 in {1.0})
#                   If (feature 0 <= 2.5)
#                    If (feature 1 <= 3.5)
#                     If (feature 2 <= 40.055673947170746)
#                      Predict: 1.0
#                     Else (feature 2 > 40.055673947170746)
#                      Predict: 0.0
#                    Else (feature 1 > 3.5)
#                     Predict: 1.0
#                   Else (feature 0 > 2.5)
#                    If (feature 19684 in {0.0})
#                     Predict: 0.0
#                    Else (feature 19684 not in {0.0})
#                     If (feature 20205 in {1.0})
#                      Predict: 0.0
#                     Else (feature 20205 not in {1.0})
#                      Predict: 1.0
#                  Else (feature 61 not in {1.0})
#                   If (feature 669 in {1.0})
#                    Predict: 1.0
#                   Else (feature 669 not in {1.0})
#                    If (feature 692 in {1.0})
#                     Predict: 1.0
#                    Else (feature 692 not in {1.0})
#                     If (feature 1046 in {1.0})
#                      Predict: 1.0
#                     Else (feature 1046 not in {1.0})
#                      If (feature 1136 in {1.0})
#                       Predict: 1.0
#                      Else (feature 1136 not in {1.0})
#                       Predict: 0.0
#             Else (feature 3 > 1.5)
#              If (feature 2 <= 132.19545823189196)
#               If (feature 20267 <= 3.5)
#                If (feature 91 in {1.0})
#                 Predict: 1.0
#                Else (feature 91 not in {1.0})
#                 If (feature 135 in {1.0})
#                  If (feature 1 <= 3.5)
#                   Predict: 1.0
#                  Else (feature 1 > 3.5)
#                   Predict: 0.0
#                 Else (feature 135 not in {1.0})
#                  If (feature 190 in {1.0})
#                   Predict: 1.0
#                  Else (feature 190 not in {1.0})
#                   If (feature 970 in {1.0})
#                    Predict: 1.0
#                   Else (feature 970 not in {1.0})
#                    If (feature 1185 in {1.0})
#                     Predict: 1.0
#                    Else (feature 1185 not in {1.0})
#                     If (feature 29 in {1.0})
#                      If (feature 2 <= 63.775164346606665)
#                       Predict: 1.0
#                      Else (feature 2 > 63.775164346606665)
#                       Predict: 0.0
#                     Else (feature 29 not in {1.0})
#                      Predict: 0.0
#               Else (feature 20267 > 3.5)
#                If (feature 23 in {1.0})
#                 If (feature 0 <= 3.5)
#                  If (feature 0 <= 2.5)
#                   Predict: 1.0
#                  Else (feature 0 > 2.5)
#                   Predict: 0.0
#                 Else (feature 0 > 3.5)
#                  Predict: 1.0
#                Else (feature 23 not in {1.0})
#                 If (feature 236 in {1.0})
#                  Predict: 1.0
#                 Else (feature 236 not in {1.0})
#                  If (feature 345 in {1.0})
#                   Predict: 1.0
#                  Else (feature 345 not in {1.0})
#                   If (feature 501 in {1.0})
#                    Predict: 1.0
#                   Else (feature 501 not in {1.0})
#                    If (feature 645 in {1.0})
#                     Predict: 1.0
#                    Else (feature 645 not in {1.0})
#                     If (feature 681 in {1.0})
#                      Predict: 1.0
#                     Else (feature 681 not in {1.0})
#                      If (feature 694 in {1.0})
#                       Predict: 1.0
#                      Else (feature 694 not in {1.0})
#                       Predict: 0.0
#              Else (feature 2 > 132.19545823189196)
#               If (feature 20220 in {1.0})
#                If (feature 2 <= 149.99905198659314)
#                 Predict: 1.0
#                Else (feature 2 > 149.99905198659314)
#                 If (feature 125 in {0.0})
#                  If (feature 597 in {0.0})
#                   Predict: 0.0
#                  Else (feature 597 not in {0.0})
#                   Predict: 1.0
#                 Else (feature 125 not in {0.0})
#                  Predict: 1.0
#               Else (feature 20220 not in {1.0})
#                If (feature 91 in {1.0})
#                 Predict: 1.0
#                Else (feature 91 not in {1.0})
#                 If (feature 23 in {1.0})
#                  If (feature 0 <= 2.5)
#                   If (feature 20267 <= 2.5)
#                    Predict: 0.0
#                   Else (feature 20267 > 2.5)
#                    Predict: 1.0
#                  Else (feature 0 > 2.5)
#                   Predict: 1.0
#                 Else (feature 23 not in {1.0})
#                  If (feature 19711 in {1.0})
#                   If (feature 7 in {1.0})
#                    Predict: 1.0
#                   Else (feature 7 not in {1.0})
#                    If (feature 20221 in {1.0})
#                     Predict: 1.0
#                    Else (feature 20221 not in {1.0})
#                     If (feature 5 in {1.0})
#                      Predict: 1.0
#                     Else (feature 5 not in {1.0})
#                      If (feature 6 in {1.0})
#                       Predict: 1.0
#                      Else (feature 6 not in {1.0})
#                       Predict: 0.0
#                  Else (feature 19711 not in {1.0})
#                   If (feature 20205 in {1.0})
#                    If (feature 2 <= 141.56717716629112)
#                     If (feature 1 <= 3.5)
#                      Predict: 0.0
#                     Else (feature 1 > 3.5)
#                      If (feature 151 in {1.0})
#                       Predict: 0.0
#                      Else (feature 151 not in {1.0})
#                       Predict: 1.0
#                    Else (feature 2 > 141.56717716629112)
#                     If (feature 151 in {1.0})
#                      Predict: 1.0
#                     Else (feature 151 not in {1.0})
#                      If (feature 195 in {1.0})
#                       Predict: 1.0
#                      Else (feature 195 not in {1.0})
#                       Predict: 0.0
#                   Else (feature 20205 not in {1.0})
#                    If (feature 29 in {1.0})
#                     Predict: 1.0
#                    Else (feature 29 not in {1.0})
#                     If (feature 43 in {1.0})
#                      Predict: 1.0
#                     Else (feature 43 not in {1.0})
#                      If (feature 141 in {1.0})
#                       Predict: 1.0
#                      Else (feature 141 not in {1.0})
#                       Predict: 0.0
#           Else (feature 1 > 6.5)
#            If (feature 20267 <= 2.5)
#             If (feature 19681 in {0.0})
#              If (feature 6 in {1.0})
#               Predict: 1.0
#              Else (feature 6 not in {1.0})
#               If (feature 1627 in {1.0})
#                Predict: 1.0
#               Else (feature 1627 not in {1.0})
#                If (feature 20214 in {1.0})
#                 If (feature 0 <= 3.5)
#                  Predict: 1.0
#                 Else (feature 0 > 3.5)
#                  Predict: 0.0
#                Else (feature 20214 not in {1.0})
#                 If (feature 588 in {1.0})
#                  Predict: 1.0
#                 Else (feature 588 not in {1.0})
#                  If (feature 634 in {1.0})
#                   Predict: 1.0
#                  Else (feature 634 not in {1.0})
#                   If (feature 714 in {1.0})
#                    Predict: 1.0
#                   Else (feature 714 not in {1.0})
#                    If (feature 749 in {1.0})
#                     Predict: 1.0
#                    Else (feature 749 not in {1.0})
#                     If (feature 848 in {1.0})
#                      Predict: 1.0
#                     Else (feature 848 not in {1.0})
#                      If (feature 1806 in {1.0})
#                       Predict: 1.0
#                      Else (feature 1806 not in {1.0})
#                       Predict: 0.0
#             Else (feature 19681 not in {0.0})
#              If (feature 3 <= 1.5)
#               If (feature 2 <= 102.92537764840822)
#                If (feature 1 <= 10.5)
#                 If (feature 23 in {1.0})
#                  Predict: 1.0
#                 Else (feature 23 not in {1.0})
#                  If (feature 90 in {1.0})
#                   Predict: 1.0
#                  Else (feature 90 not in {1.0})
#                   If (feature 91 in {1.0})
#                    Predict: 1.0
#                   Else (feature 91 not in {1.0})
#                    If (feature 189 in {1.0})
#                     Predict: 1.0
#                    Else (feature 189 not in {1.0})
#                     If (feature 368 in {1.0})
#                      Predict: 1.0
#                     Else (feature 368 not in {1.0})
#                      If (feature 466 in {1.0})
#                       Predict: 1.0
#                      Else (feature 466 not in {1.0})
#                       Predict: 0.0
#                Else (feature 1 > 10.5)
#                 If (feature 17 in {1.0})
#                  Predict: 1.0
#                 Else (feature 17 not in {1.0})
#                  If (feature 1 <= 17.5)
#                   If (feature 27 in {1.0})
#                    Predict: 1.0
#                   Else (feature 27 not in {1.0})
#                    If (feature 1 <= 12.5)
#                     If (feature 38 in {1.0})
#                      Predict: 1.0
#                     Else (feature 38 not in {1.0})
#                      If (feature 256 in {1.0})
#                       Predict: 1.0
#                      Else (feature 256 not in {1.0})
#                       Predict: 0.0
#                    Else (feature 1 > 12.5)
#                     If (feature 20206 in {1.0})
#                      Predict: 1.0
#                     Else (feature 20206 not in {1.0})
#                      If (feature 2 <= 63.775164346606665)
#                       Predict: 1.0
#                      Else (feature 2 > 63.775164346606665)
#                       Predict: 0.0
#                  Else (feature 1 > 17.5)
#                   If (feature 19694 in {0.0})
#                    If (feature 11 in {0.0})
#                     Predict: 0.0
#                    Else (feature 11 not in {0.0})
#                     Predict: 1.0
#                   Else (feature 19694 not in {0.0})
#                    Predict: 1.0
#               Else (feature 2 > 102.92537764840822)
#                If (feature 1 <= 15.5)
#                 If (feature 2 <= 149.99905198659314)
#                  If (feature 19780 in {1.0})
#                   Predict: 0.0
#                  Else (feature 19780 not in {1.0})
#                   If (feature 9 in {1.0})
#                    Predict: 0.0
#                   Else (feature 9 not in {1.0})
#                    If (feature 24 in {1.0})
#                     Predict: 0.0
#                    Else (feature 24 not in {1.0})
#                     If (feature 20212 in {1.0})
#                      Predict: 0.0
#                     Else (feature 20212 not in {1.0})
#                      If (feature 20227 in {1.0})
#                       Predict: 0.0
#                      Else (feature 20227 not in {1.0})
#                       Predict: 1.0
#                 Else (feature 2 > 149.99905198659314)
#                  If (feature 0 <= 2.5)
#                   If (feature 4 in {1.0})
#                    Predict: 1.0
#                   Else (feature 4 not in {1.0})
#                    If (feature 13 in {1.0})
#                     Predict: 1.0
#                    Else (feature 13 not in {1.0})
#                     If (feature 1 <= 10.5)
#                      If (feature 1 <= 7.5)
#                       Predict: 0.0
#                      Else (feature 1 > 7.5)
#                       Predict: 1.0
#                     Else (feature 1 > 10.5)
#                      Predict: 0.0
#                  Else (feature 0 > 2.5)
#                   If (feature 61 in {0.0})
#                    If (feature 621 in {0.0})
#                     Predict: 0.0
#                    Else (feature 621 not in {0.0})
#                     Predict: 1.0
#                   Else (feature 61 not in {0.0})
#                    Predict: 1.0
#                Else (feature 1 > 15.5)
#                 If (feature 466 in {0.0})
#                  If (feature 6527 in {0.0})
#                   Predict: 0.0
#                  Else (feature 6527 not in {0.0})
#                   Predict: 1.0
#                 Else (feature 466 not in {0.0})
#                  Predict: 1.0
#              Else (feature 3 > 1.5)
#               If (feature 20209 in {1.0})
#                If (feature 855 in {1.0})
#                 Predict: 0.0
#                Else (feature 855 not in {1.0})
#                 Predict: 1.0
#               Else (feature 20209 not in {1.0})
#                If (feature 19711 in {1.0})
#                 Predict: 1.0
#                Else (feature 19711 not in {1.0})
#                 If (feature 1 <= 10.5)
#                  If (feature 23 in {1.0})
#                   Predict: 1.0
#                  Else (feature 23 not in {1.0})
#                   If (feature 11 in {1.0})
#                    Predict: 1.0
#                   Else (feature 11 not in {1.0})
#                    If (feature 20219 in {1.0})
#                     Predict: 1.0
#                    Else (feature 20219 not in {1.0})
#                     If (feature 16 in {1.0})
# ...
#                 Predict: 1.0
#               Else (feature 19708 not in {1.0})
#                If (feature 10 in {1.0})
#                 Predict: 1.0
#                Else (feature 10 not in {1.0})
#                 If (feature 90 in {1.0})
#                  Predict: 1.0
#                 Else (feature 90 not in {1.0})
#                  If (feature 163 in {1.0})
#                   Predict: 1.0
#                  Else (feature 163 not in {1.0})
#                   If (feature 460 in {1.0})
#                    Predict: 1.0
#                   Else (feature 460 not in {1.0})
#                    If (feature 642 in {1.0})
#                     Predict: 1.0
#                    Else (feature 642 not in {1.0})
#                     If (feature 723 in {1.0})
#                      Predict: 1.0
#                     Else (feature 723 not in {1.0})
#                      If (feature 1490 in {1.0})
#                       Predict: 1.0
#                      Else (feature 1490 not in {1.0})
#                       Predict: 0.0
#          Else (feature 3 > 111.5)
#           If (feature 20267 <= 48.5)
#            If (feature 2 <= 137.28688600971873)
#             If (feature 20 in {1.0})
#              Predict: 1.0
#             Else (feature 20 not in {1.0})
#              If (feature 32 in {1.0})
#               Predict: 1.0
#              Else (feature 32 not in {1.0})
#               If (feature 1654 in {0.0})
#                If (feature 8 in {0.0})
#                 Predict: 0.0
#                Else (feature 8 not in {0.0})
#                 If (feature 1 <= 533.5)
#                  Predict: 1.0
#                 Else (feature 1 > 533.5)
#                  Predict: 0.0
#               Else (feature 1654 not in {0.0})
#                Predict: 1.0
#            Else (feature 2 > 137.28688600971873)
#             If (feature 19707 in {1.0})
#              If (feature 1 <= 388.5)
#               Predict: 1.0
#              Else (feature 1 > 388.5)
#               If (feature 1331 in {0.0})
#                Predict: 0.0
#               Else (feature 1331 not in {0.0})
#                Predict: 1.0
#             Else (feature 19707 not in {1.0})
#              If (feature 3 <= 168.5)
#               If (feature 20208 in {1.0})
#                If (feature 34 in {1.0})
#                 Predict: 0.0
#                Else (feature 34 not in {1.0})
#                 If (feature 5 in {1.0})
#                  If (feature 1 <= 470.5)
#                   Predict: 1.0
#                  Else (feature 1 > 470.5)
#                   Predict: 0.0
#                 Else (feature 5 not in {1.0})
#                  Predict: 1.0
#               Else (feature 20208 not in {1.0})
#                If (feature 20268 <= 5.5)
#                 If (feature 3 <= 164.5)
#                  If (feature 3 <= 113.5)
#                   Predict: 0.0
#                  Else (feature 3 > 113.5)
#                   If (feature 19681 in {0.0})
#                    Predict: 0.0
#                   Else (feature 19681 not in {0.0})
#                    If (feature 20268 <= 3.5)
#                     If (feature 2 <= 276.6673563174295)
#                      If (feature 3 <= 132.5)
#                       Predict: 0.0
#                      Else (feature 3 > 132.5)
#                       Predict: 1.0
#                     Else (feature 2 > 276.6673563174295)
#                      Predict: 0.0
#                    Else (feature 20268 > 3.5)
#                     Predict: 1.0
#                 Else (feature 3 > 164.5)
#                  If (feature 31 in {0.0})
#                   Predict: 0.0
#                  Else (feature 31 not in {0.0})
#                   Predict: 1.0
#                Else (feature 20268 > 5.5)
#                 If (feature 3 <= 149.5)
#                  If (feature 1 <= 388.5)
#                   Predict: 1.0
#                  Else (feature 1 > 388.5)
#                   Predict: 0.0
#                 Else (feature 3 > 149.5)
#                  If (feature 3 <= 159.5)
#                   If (feature 264 in {1.0})
#                    Predict: 0.0
#                   Else (feature 264 not in {1.0})
#                    Predict: 1.0
#                  Else (feature 3 > 159.5)
#                   Predict: 0.0
#              Else (feature 3 > 168.5)
#               Predict: 1.0
#           Else (feature 20267 > 48.5)
#            If (feature 134 in {1.0})
#             Predict: 1.0
#            Else (feature 134 not in {1.0})
#             If (feature 1 <= 622.5)
#              If (feature 20267 <= 50.5)
#               Predict: 0.0
#              Else (feature 20267 > 50.5)
#               If (feature 3 <= 126.5)
#                Predict: 1.0
#               Else (feature 3 > 126.5)
#                If (feature 3 <= 152.5)
#                 If (feature 1811 in {0.0})
#                  Predict: 0.0
#                 Else (feature 1811 not in {0.0})
#                  Predict: 1.0
#                Else (feature 3 > 152.5)
#                 Predict: 1.0
#             Else (feature 1 > 622.5)
#              If (feature 183 in {1.0})
#               Predict: 1.0
#              Else (feature 183 not in {1.0})
#               If (feature 184 in {1.0})
#                Predict: 1.0
#               Else (feature 184 not in {1.0})
#                If (feature 2012 in {0.0})
#                 If (feature 19723 in {0.0})
#                  Predict: 0.0
#                 Else (feature 19723 not in {0.0})
#                  Predict: 1.0
#                Else (feature 2012 not in {0.0})
#                 Predict: 1.0
#         Else (feature 2 > 496.7612476145354)
#          If (feature 20210 in {1.0})
#           Predict: 0.0
#          Else (feature 20210 not in {1.0})
#           If (feature 1952 in {1.0})
#            Predict: 0.0
#           Else (feature 1952 not in {1.0})
#            Predict: 1.0
#        Else (feature 20268 > 14.5)
#         If (feature 1 <= 622.5)
#          If (feature 19754 in {1.0})
#           Predict: 0.0
#          Else (feature 19754 not in {1.0})
#           If (feature 19707 in {1.0})
#            If (feature 3 <= 141.5)
#             Predict: 0.0
#            Else (feature 3 > 141.5)
#             Predict: 1.0
#           Else (feature 19707 not in {1.0})
#            If (feature 3 <= 77.5)
#             If (feature 637 in {0.0})
#              Predict: 0.0
#             Else (feature 637 not in {0.0})
#              Predict: 1.0
#            Else (feature 3 > 77.5)
#             If (feature 20207 in {1.0})
#              If (feature 2 <= 160.94817301576055)
#               Predict: 1.0
#              Else (feature 2 > 160.94817301576055)
#               If (feature 1 <= 388.5)
#                Predict: 1.0
#               Else (feature 1 > 388.5)
#                Predict: 0.0
#             Else (feature 20207 not in {1.0})
#              If (feature 59 in {1.0})
#               Predict: 0.0
#              Else (feature 59 not in {1.0})
#               If (feature 129 in {1.0})
#                Predict: 0.0
#               Else (feature 129 not in {1.0})
#                If (feature 239 in {1.0})
#                 Predict: 0.0
#                Else (feature 239 not in {1.0})
#                 If (feature 48 in {1.0})
#                  If (feature 3 <= 90.5)
#                   Predict: 0.0
#                  Else (feature 3 > 90.5)
#                   Predict: 1.0
#                 Else (feature 48 not in {1.0})
#                  Predict: 1.0
#         Else (feature 1 > 622.5)
#          If (feature 3 <= 130.5)
#           If (feature 20267 <= 40.5)
#            If (feature 2 <= 137.28688600971873)
#             If (feature 3 <= 111.5)
#              Predict: 0.0
#             Else (feature 3 > 111.5)
#              Predict: 1.0
#            Else (feature 2 > 137.28688600971873)
#             Predict: 1.0
#           Else (feature 20267 > 40.5)
#            If (feature 2 <= 266.79132576140046)
#             If (feature 13 in {1.0})
#              Predict: 1.0
#             Else (feature 13 not in {1.0})
#              If (feature 110 in {1.0})
#               Predict: 1.0
#              Else (feature 110 not in {1.0})
#               If (feature 4850 in {0.0})
#                If (feature 5620 in {0.0})
#                 Predict: 0.0
#                Else (feature 5620 not in {0.0})
#                 Predict: 1.0
#               Else (feature 4850 not in {0.0})
#                Predict: 1.0
#            Else (feature 2 > 266.79132576140046)
#             Predict: 1.0
#          Else (feature 3 > 130.5)
#           If (feature 20207 in {1.0})
#            If (feature 2 <= 63.775164346606665)
#             Predict: 1.0
#            Else (feature 2 > 63.775164346606665)
#             Predict: 0.0
#           Else (feature 20207 not in {1.0})
#            If (feature 423 in {1.0})
#             Predict: 0.0
#            Else (feature 423 not in {1.0})
#             Predict: 1.0
#      Else (feature 3 > 178.5)
#       If (feature 20267 <= 48.5)
#        If (feature 19758 in {1.0})
#         If (feature 36 in {0.0})
#          Predict: 0.0
#         Else (feature 36 not in {0.0})
#          Predict: 1.0
#        Else (feature 19758 not in {1.0})
#         If (feature 19707 in {1.0})
#          If (feature 3 <= 203.5)
#           If (feature 20267 <= 27.5)
#            Predict: 1.0
#           Else (feature 20267 > 27.5)
#            Predict: 0.0
#          Else (feature 3 > 203.5)
#           If (feature 3 <= 280.5)
#            If (feature 20267 <= 41.5)
#             If (feature 76 in {1.0})
#              Predict: 0.0
#             Else (feature 76 not in {1.0})
#              Predict: 1.0
#            Else (feature 20267 > 41.5)
#             If (feature 20268 <= 6.5)
#              If (feature 1 <= 1013.5)
#               Predict: 0.0
#              Else (feature 1 > 1013.5)
#               Predict: 1.0
#             Else (feature 20268 > 6.5)
#              Predict: 1.0
#           Else (feature 3 > 280.5)
#            If (feature 19 in {1.0})
#             Predict: 0.0
#            Else (feature 19 not in {1.0})
#             If (feature 65 in {1.0})
#              Predict: 0.0
#             Else (feature 65 not in {1.0})
#              If (feature 323 in {1.0})
#               Predict: 0.0
#              Else (feature 323 not in {1.0})
#               Predict: 1.0
#         Else (feature 19707 not in {1.0})
#          If (feature 412 in {1.0})
#           Predict: 0.0
#          Else (feature 412 not in {1.0})
#           If (feature 19709 in {1.0})
#            If (feature 20268 <= 5.5)
#             If (feature 20267 <= 33.5)
#              If (feature 1 <= 533.5)
#               Predict: 0.0
#              Else (feature 1 > 533.5)
#               Predict: 1.0
#             Else (feature 20267 > 33.5)
#              If (feature 20267 <= 43.5)
#               If (feature 8 in {0.0})
#                Predict: 0.0
#               Else (feature 8 not in {0.0})
#                Predict: 1.0
#              Else (feature 20267 > 43.5)
#               Predict: 1.0
#            Else (feature 20268 > 5.5)
#             If (feature 20 in {1.0})
#              Predict: 0.0
#             Else (feature 20 not in {1.0})
#              If (feature 35 in {1.0})
#               Predict: 0.0
#              Else (feature 35 not in {1.0})
#               If (feature 44 in {1.0})
#                Predict: 0.0
#               Else (feature 44 not in {1.0})
#                Predict: 1.0
#           Else (feature 19709 not in {1.0})
#            If (feature 15 in {1.0})
#             Predict: 0.0
#            Else (feature 15 not in {1.0})
#             If (feature 86 in {1.0})
#              Predict: 0.0
#             Else (feature 86 not in {1.0})
#              If (feature 180 in {1.0})
#               Predict: 0.0
#              Else (feature 180 not in {1.0})
#               If (feature 235 in {1.0})
#                Predict: 0.0
#               Else (feature 235 not in {1.0})
#                If (feature 259 in {1.0})
#                 Predict: 0.0
#                Else (feature 259 not in {1.0})
#                 If (feature 276 in {1.0})
#                  Predict: 0.0
#                 Else (feature 276 not in {1.0})
#                  If (feature 339 in {1.0})
#                   Predict: 0.0
#                  Else (feature 339 not in {1.0})
#                   If (feature 420 in {1.0})
#                    Predict: 0.0
#                   Else (feature 420 not in {1.0})
#                    If (feature 1034 in {1.0})
#                     Predict: 0.0
#                    Else (feature 1034 not in {1.0})
#                     If (feature 1296 in {1.0})
#                      Predict: 0.0
#                     Else (feature 1296 not in {1.0})
#                      If (feature 1988 in {1.0})
#                       Predict: 0.0
#                      Else (feature 1988 not in {1.0})
#                       Predict: 1.0
#       Else (feature 20267 > 48.5)
#        If (feature 3 <= 280.5)
#         If (feature 20268 <= 6.5)
#          If (feature 20267 <= 49.5)
#           If (feature 2 <= 107.54504176465326)
#            Predict: 0.0
#           Else (feature 2 > 107.54504176465326)
#            If (feature 3 <= 198.5)
#             Predict: 0.0
#            Else (feature 3 > 198.5)
#             Predict: 1.0
#          Else (feature 20267 > 49.5)
#           If (feature 20267 <= 60.5)
#            If (feature 2 <= 171.66144313962997)
#             If (feature 1 <= 1013.5)
#              If (feature 1425 in {1.0})
#               Predict: 0.0
#              Else (feature 1425 not in {1.0})
#               Predict: 1.0
#             Else (feature 1 > 1013.5)
#              Predict: 0.0
#            Else (feature 2 > 171.66144313962997)
#             If (feature 203 in {1.0})
#              Predict: 1.0
#             Else (feature 203 not in {1.0})
#              If (feature 36 in {1.0})
#               Predict: 1.0
#              Else (feature 36 not in {1.0})
#               If (feature 52 in {1.0})
#                Predict: 1.0
#               Else (feature 52 not in {1.0})
#                If (feature 306 in {0.0})
#                 If (feature 531 in {0.0})
#                  Predict: 0.0
#                 Else (feature 531 not in {0.0})
#                  Predict: 1.0
#                Else (feature 306 not in {0.0})
#                 Predict: 1.0
#           Else (feature 20267 > 60.5)
#            If (feature 128 in {1.0})
#             Predict: 0.0
#            Else (feature 128 not in {1.0})
#             Predict: 1.0
#         Else (feature 20268 > 6.5)
#          If (feature 20268 <= 23.5)
#           Predict: 1.0
#          Else (feature 20268 > 23.5)
#           If (feature 20212 in {1.0})
#            Predict: 0.0
#           Else (feature 20212 not in {1.0})
#            If (feature 62 in {1.0})
#             Predict: 0.0
#            Else (feature 62 not in {1.0})
#             If (feature 237 in {1.0})
#              Predict: 0.0
#             Else (feature 237 not in {1.0})
#              If (feature 5147 in {1.0})
#               Predict: 0.0
#              Else (feature 5147 not in {1.0})
#               Predict: 1.0
#        Else (feature 3 > 280.5)
#         If (feature 20211 in {1.0})
#          If (feature 2 <= 196.9641887499629)
#           Predict: 0.0
#          Else (feature 2 > 196.9641887499629)
#           Predict: 1.0
#         Else (feature 20211 not in {1.0})
#          If (feature 2 <= 40.055673947170746)
#           Predict: 0.0
#          Else (feature 2 > 40.055673947170746)
#           If (feature 84 in {1.0})
#            Predict: 0.0
#           Else (feature 84 not in {1.0})
#            If (feature 155 in {1.0})
#             Predict: 0.0
#            Else (feature 155 not in {1.0})
#             If (feature 234 in {1.0})
#              Predict: 0.0
#             Else (feature 234 not in {1.0})
#              If (feature 540 in {1.0})
#               Predict: 0.0
#              Else (feature 540 not in {1.0})
#               If (feature 901 in {1.0})
#                Predict: 0.0
#               Else (feature 901 not in {1.0})
#                If (feature 1042 in {1.0})
#                 Predict: 0.0
#                Else (feature 1042 not in {1.0})
#                 If (feature 3442 in {1.0})
#                  Predict: 0.0
#                 Else (feature 3442 not in {1.0})
#                  If (feature 237 in {1.0})
#                   If (feature 20267 <= 52.5)
#                    Predict: 1.0
#                   Else (feature 20267 > 52.5)
#                    If (feature 20267 <= 59.5)
#                     Predict: 0.0
#                    Else (feature 20267 > 59.5)
#                     Predict: 1.0
#                  Else (feature 237 not in {1.0})
#                   Predict: 1.0

# %%
dtpredicts = dtmodel.transform(payments_valid)

# %%
dtpredicts.show()
# Out:
# +--------------------+-----+---------------+--------------------+----------+
# |            features|label|  rawPrediction|         probability|prediction|
# +--------------------+-----+---------------+--------------------+----------+
# |(20269,[0,1,2,3,4...|    0| [5776.0,130.0]|[0.97798848628513...|       0.0|
# |(20269,[0,1,2,3,6...|    0|      [7.0,0.0]|           [1.0,0.0]|       0.0|
# |(20269,[0,1,2,3,7...|    0| [6500.0,819.0]|[0.88809946714031...|       0.0|
# |(20269,[0,1,2,3,9...|    0| [5679.0,272.0]|[0.95429339606788...|       0.0|
# |(20269,[0,1,2,3,1...|    0|     [26.0,0.0]|           [1.0,0.0]|       0.0|
# |(20269,[0,1,2,3,1...|    0|[32763.0,594.0]|[0.98219264322331...|       0.0|
# |(20269,[0,1,2,3,1...|    0| [5326.0,142.0]|[0.97403072421360...|       0.0|
# |(20269,[0,1,2,3,1...|    0|  [1286.0,65.0]|[0.95188749074759...|       0.0|
# |(20269,[0,1,2,3,2...|    0|[32763.0,594.0]|[0.98219264322331...|       0.0|
# |(20269,[0,1,2,3,2...|    0| [5326.0,142.0]|[0.97403072421360...|       0.0|
# |(20269,[0,1,2,3,2...|    1|   [267.0,35.0]|[0.88410596026490...|       0.0|
# |(20269,[0,1,2,3,3...|    0|  [4349.0,58.0]|[0.98683911958248...|       0.0|
# |(20269,[0,1,2,3,3...|    0| [5326.0,142.0]|[0.97403072421360...|       0.0|
# |(20269,[0,1,2,3,4...|    0| [5800.0,531.0]|[0.91612699415574...|       0.0|
# |(20269,[0,1,2,3,4...|    1|  [1148.0,93.0]|[0.92506043513295...|       0.0|
# |(20269,[0,1,2,3,4...|    0| [1646.0,103.0]|[0.94110920526014...|       0.0|
# |(20269,[0,1,2,3,4...|    0|     [0.0,24.0]|           [0.0,1.0]|       1.0|
# |(20269,[0,1,2,3,5...|    0|   [149.0,67.0]|[0.68981481481481...|       0.0|
# |(20269,[0,1,2,3,5...|    0|[32763.0,594.0]|[0.98219264322331...|       0.0|
# |(20269,[0,1,2,3,5...|    0| [4305.0,283.0]|[0.93831734960767...|       0.0|
# +--------------------+-----+---------------+--------------------+----------+
# only showing top 20 rows

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(dtpredicts)
print "Test Error : " 
error = 1.0 - accuracy
print error
# Out:
# Test Error :
# 0.0824877604287

# %%
print accuracy
# Out:
# 0.917512239571

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="f1")
f_one = evaluator.evaluate(dtpredicts)
print "F1 Score : "
print f_one
# Out:
# F1 Score :
# 0.906199658466

# %%
dtpredicts.select('label','prediction').groupBy('label','prediction').count().show(100)
# Out:
# +-----+----------+------+
# |label|prediction| count|
# +-----+----------+------+
# |    1|       0.0| 12456|
# |    0|       0.0|171374|
# |    1|       1.0|  6850|
# |    0|       1.0|  3567|
# +-----+----------+------+
